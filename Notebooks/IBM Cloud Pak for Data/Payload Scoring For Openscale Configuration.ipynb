# %% [markdown]
# ## In this simple notebook we shall run some payload scoring so we can monitor with Watson Openscale

# %%
from watson_machine_learning_client import WatsonMachineLearningAPIClient

# %%
# Specify the credentials for Watson Machine Learning
#@hidden_cell
wml_credentials = {
    "url": "<the url of cp4d without the port>"",
    "username": "<your user id with administrator permission>",
    "password": ">your password",
    "instance_id": "icp"               
}

wml_client = WatsonMachineLearningAPIClient(wml_credentials)

# %%
wml_client.deployments.list()
# Out:
# ------------------------------------  -------------------------------------------  ------  --------------  ------------------------  -----------------  -------------
# GUID                                  NAME                                         TYPE    STATE           CREATED                   FRAMEWORK          ARTIFACT TYPE
# 468a584c-bafe-4101-8caf-e391ba8588a4  Customer Churn ICP4D function deployment v6  online  DEPLOY_SUCCESS  2019-09-17T21:41:29.363Z  n/a                function
# 36ea79b2-4e4e-4a72-937c-703cd0535084  churn-model-in-cp4d-wml-dep1                 online  DEPLOY_SUCCESS  2019-09-17T19:01:59.099Z  mllib-2.3          model
# 6e3470a3-4a95-4a42-a050-121a4a51ac13  GermanCreditRiskModelICP                     online  DEPLOY_SUCCESS  2019-09-17T16:32:06.303Z  mllib-2.3          model
# fc8d97e7-584b-498b-8f63-d6409ec08b78  HouseCreditRiskModelICP                      online  DEPLOY_SUCCESS  2019-09-17T15:58:22.893Z  scikit-learn-0.19  model
# ...

# %% [markdown]
# #### Identify the right deployment id from the above list corresponding to the deployment to which you want to send the scoring request.
# #### Use the same deployment id to get deployment details in the next cell

# %%
deployment_details = wml_client.deployments.get_details('468a584c-bafe-4101-8caf-e391ba8588a4')

# %%
icp4d_churn_scoring_url = deployment_details['entity']['scoring_url']
print(icp4d_churn_scoring_url)
# Out:
# https://52.116.34.23:31843/v3/scoring/online/468a584c-bafe-4101-8caf-e391ba8588a4

# %%
# Payload scoring
fields = ["GENDER", "STATUS", "CAROWNER", "PAYMETHOD", "LOCALBILLTYPE", \
          "LONGDISTANCEBILLTYPE", "PHASE", "CHILDREN", "ESTINCOME", "AGE", "LONGDISTANCE", "INTERNATIONAL", "LOCAL",\
          "DROPPED","USAGE","RATEPLAN"]

# %%
values = [["M", "M", "Y", "CC", "Budget", "Standard", "Adult", 2.0, 77551.00, 33, 20.53, 0.0, 41.89, 1.0, 62.42, 2.0],\
          ["M", "M", "N", "CC", "Budget", "Standard", "Adult", 0.0, 50000.00, 21, 10.53, 0.0, 41.89, 1.0, 62.42, 1.0],\
          ["F", "M", "Y", "CC", "Budget", "Standard", "Adult", 0.0, 55000.00, 20, 10.53, 0.0, 41.89, 1.0, 62.42, 1.0],\
          ["F", "M", "N", "CC", "Budget", "Standard", "Adult", 0.0, 55000.00, 20, 10.53, 0.0, 41.89, 1.0, 62.42, 2.0],\
          ["F", "M", "Y", "CC", "Budget", "Standard", "Adult", 0.0, 50000.00, 21, 10.53, 0.0, 41.89, 1.0, 62.42, 1.0],\
          ["M", "M", "Y", "CC", "Budget", "Standard", "Adult", 3.0, 155000.00, 40, 10.53, 0.0, 41.89, 1.0, 62.42, 1.0],\
          ["M", "M", "Y", "CC", "Budget", "Standard", "Adult", 1.0, 165000.00, 40, 10.53, 0.0, 41.89, 1.0, 62.42, 2.0],\
          ["M", "M", "N", "CC", "Budget", "Standard", "Adult", 1.0, 50000.00, 21, 10.53, 0.0, 41.89, 1.0, 62.42, 1.0],\
          ["F", "M", "N", "CC", "Budget", "Standard", "Adult", 0.0, 55000.00, 20, 10.53, 0.0, 41.89, 1.0, 62.42, 1.0],\
          ["F", "M", "N", "CC", "Budget", "Standard", "Adult", 1.0, 85000.00, 29, 10.53, 0.0, 41.89, 1.0, 62.42, 2.0],\
          ["F", "M", "Y", "CC", "Budget", "Standard", "Adult", 0.0, 70000.00, 21, 10.53, 0.0, 41.89, 1.0, 62.42, 1.0],\
          ["F", "M", "N", "CC", "Budget", "Standard", "Adult", 3.0, 175000.00, 40, 10.53, 0.0, 41.89, 1.0, 62.42, 1.0],\
          ["M", "M", "N", "CC", "Budget", "Standard", "Adult", 1.0, 145000.00, 40, 10.53, 0.0, 41.89, 1.0, 62.42, 2.0],\
          ["M", "M", "N", "CC", "Budget", "Standard", "Adult", 1.0, 150000.00, 31, 10.53, 0.0, 41.89, 1.0, 62.42, 1.0],\
          ["F", "M", "Y", "CC", "Budget", "Standard", "Adult", 1.0, 155000.00, 30, 10.53, 0.0, 41.89, 1.0, 62.42, 1.0],\
          ["F", "M", "N", "CC", "Budget", "Standard", "Adult", 1.0, 155000.00, 30, 10.53, 0.0, 41.89, 1.0, 62.42, 2.0],\
          ["F", "M", "Y", "CC", "Budget", "Standard", "Adult", 1.0, 150000.00, 33, 10.53, 0.0, 41.89, 1.0, 62.42, 1.0],\
          ["M", "M", "Y", "CC", "Budget", "Standard", "Adult", 3.0, 155000.00, 30, 10.53, 0.0, 41.89, 1.0, 62.42, 1.0],\
          ["M", "M", "Y", "CC", "Budget", "Standard", "Adult", 1.0, 165000.00, 30, 10.53, 0.0, 41.89, 1.0, 62.42, 2.0],\
          ["M", "M", "Y", "CC", "Budget", "Standard", "Adult", 1.0, 150000.00, 31, 10.53, 0.0, 41.89, 1.0, 62.42, 1.0],\
          ["F", "M", "Y", "CC", "Budget", "Standard", "Adult", 0.0, 155000.00, 30, 10.53, 0.0, 41.89, 1.0, 62.42, 1.0],\
          ["F", "M", "Y", "CC", "Budget", "Standard", "Adult", 1.0, 185000.00, 39, 10.53, 0.0, 41.89, 1.0, 62.42, 2.0],\
          ["F", "M", "Y", "CC", "Budget", "Standard", "Adult", 0.0, 170000.00, 31, 10.53, 0.0, 41.89, 1.0, 62.42, 1.0],\
          ["F", "M", "Y", "CC", "Budget", "Standard", "Adult", 3.0, 170000.00, 30, 10.53, 0.0, 41.89, 1.0, 62.42, 1.0],\
          ["M", "M", "Y", "CC", "Budget", "Standard", "Adult", 1.0, 140000.00, 30, 10.53, 0.0, 41.89, 1.0, 62.42, 2.0],\
          ["F", "M", "Y", "CC", "Budget", "Standard", "Adult", 1.0, 100000.00, 23, 200.53, 0.0, 145.00, 5.0, 100.42, 1.0]]

# %%
payload_scoring = {"fields": fields,"values": values}

# %%
scoring_response = wml_client.deployments.score(icp4d_churn_scoring_url, payload_scoring, "custchurn_rfc1")

# %%
scoring_response
# Out:
# {'values': [['M',
#    'M',
#    'Y',
#    'CC',
#    'Budget',
#    'Standard',
#    'Adult',
#    2.0,
#    77551.0,
#    33,
#    20.53,
#    0.0,
#    41.89,
#    1.0,
#    62.42,
#    2.0,
#    [0.7659981290980407, 0.23400187090195942],
#    0.0,
#    'F'],
#   ['M',
#    'M',
#    'N',
#    'CC',
#    'Budget',
#    'Standard',
#    'Adult',
#    0.0,
#    50000.0,
#    21,
#    10.53,
#    0.0,
#    41.89,
#    1.0,
#    62.42,
#    1.0,
#    [0.651898764594198, 0.348101235405802],
#    0.0,
#    'F'],
#   ['F',
#    'M',
#    'Y',
#    'CC',
#    'Budget',
#    'Standard',
#    'Adult',
#    0.0,
#    55000.0,
#    20,
#    10.53,
#    0.0,
#    41.89,
#    1.0,
#    62.42,
#    1.0,
#    [0.6678251931439729, 0.3321748068560271],
#    0.0,
#    'F'],
#   ['F',
#    'M',
#    'N',
#    'CC',
#    'Budget',
#    'Standard',
#    'Adult',
#    0.0,
#    55000.0,
#    20,
#    10.53,
#    0.0,
#    41.89,
#    1.0,
#    62.42,
#    2.0,
# ...
